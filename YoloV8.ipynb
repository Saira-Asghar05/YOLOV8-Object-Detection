# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/yolov8
# Out:
# /content/drive/MyDrive/yolov8

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/traffic_video.mp4" conf=0.50 'save= True'
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# Intel MKL FATAL ERROR: Cannot load /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so.

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/BUS_8_jpeg.rf.68dc2cb82114aa9e759e0cc6a932585a.jpg" conf=0.50 'save= True'
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/BUS_8_jpeg.rf.68dc2cb82114aa9e759e0cc6a932585a.jpg: 640x640 1 bus, 7.8ms
# Speed: 3.7ms preprocess, 7.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/24Ambulance_jpg.rf.031605476c0ea1e3e495d3a4b2fa1edd.jpg" conf=0.50 'save= True'
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/24Ambulance_jpg.rf.031605476c0ea1e3e495d3a4b2fa1edd.jpg: 640x640 1 bus, 7.9ms
# Speed: 3.5ms preprocess, 7.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **Training yolov8 on Custom Dataset**

# %%
# !yolo task=detect model=train model=yolov8n.pt data ="/content/drive/MyDrive/yolov8/dataset/vehicle_data.yaml" epochs=50 imgsz = 600 'save= True'
# Out:
# WARNING ⚠️ 'mode' is missing. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark'). Using default 'mode=train'.
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Detecting objects in the test images using best.pt weights from custom dataset training of yolov8.

# %%
# !yolo task=detect mode=predict model= "/content/drive/MyDrive/yolov8/runs/detect/train7/weights/best.pt" source= "/content/drive/MyDrive/yolov8/dataset/test/images" conf=0.50 'save= True'
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1233 /content/drive/MyDrive/yolov8/dataset/test/images/100car_jpg.rf.5f0e5a412e76945aaf744840da4f9604.jpg: 608x608 1 Ambulance, 8.6ms
# image 2/1233 /content/drive/MyDrive/yolov8/dataset/test/images/101Ambulance_jpg.rf.f97b5ceed62bb2637e2591f420871cda.jpg: 608x608 1 Ambulance, 7.5ms
# image 3/1233 /content/drive/MyDrive/yolov8/dataset/test/images/101car_jpg.rf.b98471406bb48d33367b24addda19f84.jpg: 608x608 1 Car, 7.5ms
# image 4/1233 /content/drive/MyDrive/yolov8/dataset/test/images/102car_jpg.rf.ebd8e894ae46af2447b26401c473358e.jpg: 608x608 1 Car, 7.4ms
# image 5/1233 /content/drive/MyDrive/yolov8/dataset/test/images/103_jpg.rf.34efd4fd23c28338f024d6247430c2c4.jpg: 608x608 1 Car, 7.3ms
# ...

# %%
# !yolo task=detect mode=predict model= "/content/drive/MyDrive/yolov8/runs/detect/train7/weights/best.pt" source= "/content/drive/MyDrive/yolov8/traffic_video.mp4" conf=0.50 'save= True'
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 3 Trucks, 89.7ms
# video 1/1 (2/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 1 Truck, 6.6ms
# video 1/1 (3/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 1 Truck, 6.7ms
# video 1/1 (4/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 2 Trucks, 6.0ms
# video 1/1 (5/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 2 Trucks, 6.0ms
# video 1/1 (6/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 2 Trucks, 6.0ms
# video 1/1 (7/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 2 Trucks, 6.0ms
# video 1/1 (8/4509) /content/drive/MyDrive/yolov8/traffic_video.mp4: 352x608 2 Trucks, 10.8ms
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/traffic_video.mp4" conf=0.50 'save= True'
